# %%
from configs import Constant

# %%
c = Constant()
print(c.__dict__)
# Out:
# {'today': Timestamp('2026-01-01 19:16:43.834275'), 'start_date': Timestamp('2026-01-01 19:16:43.834298910'), 'root_dir': PosixPath('/Users/artem/Documents/Zerich/polar_vortex/app'), 'fact_dir': PosixPath('/Users/artem/Documents/Zerich/polar_vortex/app/data/fact'), 'forecast_dir': PosixPath('/Users/artem/Documents/Zerich/polar_vortex/app/data/forecast')}

# %%
c.fact_dir
# Out:
# PosixPath('/Users/artem/Documents/Zerich/polar_vortex/app/data/fact')

# %%
from pathlib import Path

# %%
p = Path("/Volumes/Artem/data/era5_centroid/era5_stratosphere_75_90N_2022.nc")

# %%
p.exists()
# Out:
# True

# %%
from configs import ERA_const

# %%
from loaders import ERA5_loader, GFS_loader
from configs import Constant, ERA_const, GFS_const

# %%
era_loader = ERA5_loader()
gfs_loader = GFS_loader()

# %%
gfs_loader.load_fact()
# Out:
# 2026-01-04 16:10:49,064 | INFO     | [FACT] 2025-12-30 .. 2026-01-04 cycle=00Z f000
# 2026-01-04 16:10:49,065 | INFO     | [FACT] download: 20251230 00Z f000
# 2026-01-04 16:10:54,852 | INFO     | [FACT] download: 20251231 00Z f000
# 2026-01-04 16:11:02,023 | INFO     | [FACT] download: 20260101 00Z f000
# 2026-01-04 16:11:08,810 | INFO     | [FACT] download: 20260102 00Z f000
# 2026-01-04 16:11:15,579 | INFO     | [FACT] download: 20260103 00Z f000
# 2026-01-04 16:11:19,895 | INFO     | [FACT] download: 20260104 00Z f000
# 2026-01-04 16:11:23,763 | INFO     | [FACT] end loading
# Ignoring index file '/Users/artem/Documents/Zerich/polar_vortex/app/data_1/fact/gfs_tmp_files/gfs_20251230_00z_f000.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/Users/artem/Documents/Zerich/polar_vortex/app/data_1/fact/gfs_tmp_files/gfs_20251231_00z_f000.grib2.5b7b6.idx' older than GRIB file
# ...

# %%
cnst = Constant()

# %%
gfs_loader.gfs_const.request
# Out:
# {'var_UGRD': 'on',
#  'var_VGRD': 'on',
#  'var_TMP': 'on',
#  'leftlon': '0',
#  'rightlon': '360',
#  'toplat': '90',
#  'bottomlat': '45',
#  'lev_10_mb': 'on',
#  'lev_50_mb': 'on',
#  'lev_100_mb': 'on'}

# %%
era_loader.const.today
# Out:
# datetime.date(2026, 1, 4)
